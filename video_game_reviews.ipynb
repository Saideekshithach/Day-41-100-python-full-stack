# %%
import pandas as pd

# %%
data=pd.read_csv("video_game_reviews.csv")
data
# Out:
#                                     Game Title  User Rating  \
# 0                           Grand Theft Auto V         36.4
# 1                                   The Sims 4         38.3
# 2                                    Minecraft         26.8
# 3                            Bioshock Infinite         38.4
# 4                              Half-Life: Alyx         30.1
# ...                                        ...          ...
# 47769                                Minecraft         41.6
# 47770  The Legend of Zelda: Breath of the Wild         24.2
# 47771            Animal Crossing: New Horizons         26.7
# 47772  The Legend of Zelda: Breath of the Wild         22.5
# 47773  The Legend of Zelda: Breath of the Wild         22.7
#
#       Age Group Targeted  Price     Platform Requires Special Device  \
# 0               All Ages  41.41           PC                      No
# 1                 Adults  57.56           PC                      No
# ...

# %%
data.columns
# Out:
# Index(['Game Title', 'User Rating', 'Age Group Targeted', 'Price', 'Platform',
#        'Requires Special Device', 'Developer', 'Publisher', 'Release Year',
#        'Genre', 'Multiplayer', 'Game Length (Hours)', 'Graphics Quality',
#        'Soundtrack Quality', 'Story Quality', 'User Review Text', 'Game Mode',
#        'Min Number of Players'],
#       dtype='object')

# %%
data.shape
# Out:
# (47774, 18)

# %%
data.info
# Out:
# <bound method DataFrame.info of                                     Game Title  User Rating  \
# 0                           Grand Theft Auto V         36.4
# 1                                   The Sims 4         38.3
# 2                                    Minecraft         26.8
# 3                            Bioshock Infinite         38.4
# 4                              Half-Life: Alyx         30.1
# ...                                        ...          ...
# 47769                                Minecraft         41.6
# 47770  The Legend of Zelda: Breath of the Wild         24.2
# 47771            Animal Crossing: New Horizons         26.7
# 47772  The Legend of Zelda: Breath of the Wild         22.5
# 47773  The Legend of Zelda: Breath of the Wild         22.7
#
#       Age Group Targeted  Price     Platform Requires Special Device  \
# 0               All Ages  41.41           PC                      No
# 1                 Adults  57.56           PC                      No
# ...

# %%
data.isnull().sum()
# Out:
# Game Title                 0
# User Rating                0
# Age Group Targeted         0
# Price                      0
# Platform                   0
# Requires Special Device    0
# Developer                  0
# Publisher                  0
# Release Year               0
# Genre                      0
# Multiplayer                0
# Game Length (Hours)        0
# Graphics Quality           0
# Soundtrack Quality         0
# Story Quality              0
# User Review Text           0
# Game Mode                  0
# Min Number of Players      0
# dtype: int64

# %%
data['User Rating']
# Out:
# 0        36.4
# 1        38.3
# 2        26.8
# 3        38.4
# 4        30.1
#          ...
# 47769    41.6
# 47770    24.2
# 47771    26.7
# 47772    22.5
# 47773    22.7
# Name: User Rating, Length: 47774, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
data.drop(columns=["Price","Game Length (Hours)","Publisher","Platform","Requires Special Device","Release Year","Game Mode","Min Number of Players","Multiplayer"],inplace=True)
data
# Out:
#                                     Game Title  User Rating  \
# 0                           Grand Theft Auto V         36.4
# 1                                   The Sims 4         38.3
# 2                                    Minecraft         26.8
# 3                            Bioshock Infinite         38.4
# 4                              Half-Life: Alyx         30.1
# ...                                        ...          ...
# 47769                                Minecraft         41.6
# 47770  The Legend of Zelda: Breath of the Wild         24.2
# 47771            Animal Crossing: New Horizons         26.7
# 47772  The Legend of Zelda: Breath of the Wild         22.5
# 47773  The Legend of Zelda: Breath of the Wild         22.7
#
#       Age Group Targeted   Developer       Genre Graphics Quality  \
# 0               All Ages  Game Freak   Adventure           Medium
# 1                 Adults    Nintendo     Shooter              Low
# ...

# %%
data['Game Title'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Game Title'>

# %%
data['User Rating'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='User Rating'>

# %%
data['Age Group Targeted'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['Developer'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Developer'>

# %%
data['Genre'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data['Graphics Quality'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Graphics Quality'>

# %%
data['Soundtrack Quality'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Soundtrack Quality'>

# %%
data['Story Quality'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data['User Review Text'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='User Review Text'>
